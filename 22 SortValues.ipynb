# %%
import pandas as pd
df = pd.read_csv('IPL Matches 2008-2020.csv')
df.head()
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
# 3  335985      Mumbai  2008-04-20      MV Boucher
# 4  335986     Kolkata  2008-04-20       DJ Hussey
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# ...

# %% [markdown]
# # Sorting Series

# %%
df['result_margin'].sort_values(ascending=False)
# Out:
# 620    146.0
# 560    144.0
# 0      140.0
# 497    138.0
# 351    130.0
#        ...
# 746      NaN
# 757      NaN
# 776      NaN
# 781      NaN
# 811      NaN
# Name: result_margin, Length: 816, dtype: float64

# %% [markdown]
# # Sorting Dataframe

# %% [markdown]
# Numerical sorting

# %%
df.sort_values('result_margin', ascending=False).head()
# Out:
#           id       city        date player_of_match                  venue  \
# 620  1082635      Delhi  2017-05-06     LMP Simmons       Feroz Shah Kotla
# 560   980987  Bangalore  2016-05-14  AB de Villiers  M Chinnaswamy Stadium
# 0     335982  Bangalore  2008-04-18     BB McCullum  M Chinnaswamy Stadium
# 497   829785  Bangalore  2015-05-06        CH Gayle  M Chinnaswamy Stadium
# 351   598027  Bangalore  2013-04-23        CH Gayle  M Chinnaswamy Stadium
#
#      neutral_venue                        team1                  team2  \
# 620              0             Delhi Daredevils         Mumbai Indians
# 560              0  Royal Challengers Bangalore          Gujarat Lions
# 0                0  Royal Challengers Bangalore  Kolkata Knight Riders
# 497              0  Royal Challengers Bangalore        Kings XI Punjab
# 351              0  Royal Challengers Bangalore          Pune Warriors
#
#                      toss_winner toss_decision                       winner  \
# ...

# %% [markdown]
# ## Categorical sorting

# %%
df.sort_values('city').head()
# Out:
#           id       city        date player_of_match                 venue  \
# 405   729293  Abu Dhabi  2014-04-21        SK Raina  Sheikh Zayed Stadium
# 416   729315  Abu Dhabi  2014-04-29     JP Faulkner  Sheikh Zayed Stadium
# 412   729307  Abu Dhabi  2014-04-26  Sandeep Sharma  Sheikh Zayed Stadium
# 411   729305  Abu Dhabi  2014-04-26        PV Tambe  Sheikh Zayed Stadium
# 814  1237180  Abu Dhabi  2020-11-08      MP Stoinis  Sheikh Zayed Stadium
#
#      neutral_venue                  team1                        team2  \
# 405              1    Chennai Super Kings             Delhi Daredevils
# 416              1  Kolkata Knight Riders             Rajasthan Royals
# 412              1  Kolkata Knight Riders              Kings XI Punjab
# 411              1       Rajasthan Royals  Royal Challengers Bangalore
# 814              0         Delhi Capitals          Sunrisers Hyderabad
#
#                toss_winner toss_decision               winner   result  \
# ...

# %% [markdown]
# ## Sorting by city first and then inside each city sorting by date

# %%
df.sort_values(['city', 'date'])
# Out:
#          id       city        date player_of_match  \
# 398  729279  Abu Dhabi  2014-04-16       JH Kallis
# 400  729283  Abu Dhabi  2014-04-18      GJ Maxwell
# 401  729285  Abu Dhabi  2014-04-18       AM Rahane
# 405  729293  Abu Dhabi  2014-04-21        SK Raina
# 411  729305  Abu Dhabi  2014-04-26        PV Tambe
# ..      ...        ...         ...             ...
# 410  729303        NaN  2014-04-25       MM Sharma
# 413  729309        NaN  2014-04-27         M Vijay
# 414  729311        NaN  2014-04-27        DR Smith
# 415  729313        NaN  2014-04-28  Sandeep Sharma
# 417  729317        NaN  2014-04-30         B Kumar
#
#                                    venue  neutral_venue                team1  \
# 398                 Sheikh Zayed Stadium              1       Mumbai Indians
# 400                 Sheikh Zayed Stadium              1  Chennai Super Kings
# 401                 Sheikh Zayed Stadium              1  Sunrisers Hyderabad
# ...

# %%
df.sort_values(['city', 'date'], ascending=[True,False])
# Out:
#           id       city        date player_of_match  \
# 814  1237180  Abu Dhabi  2020-11-08      MP Stoinis
# 813  1237178  Abu Dhabi  2020-11-06   KS Williamson
# 769  1216505  Abu Dhabi  2020-11-02        A Nortje
# 770  1216506  Abu Dhabi  2020-11-01      RD Gaikwad
# 801  1216537  Abu Dhabi  2020-10-30       BA Stokes
# ..       ...        ...         ...             ...
# 406   729295        NaN  2014-04-22      GJ Maxwell
# 404   729291        NaN  2014-04-20      GJ Maxwell
# 402   729287        NaN  2014-04-19        PA Patel
# 403   729289        NaN  2014-04-19       JP Duminy
# 399   729281        NaN  2014-04-17       YS Chahal
#
#                                    venue  neutral_venue  \
# 814                 Sheikh Zayed Stadium              0
# 813                 Sheikh Zayed Stadium              0
# 769                 Sheikh Zayed Stadium              0
# 770                 Sheikh Zayed Stadium              0
# ...
